# %%
import os                                     
import tensorflow as tf
from tensorflow.keras import layers, models                                  # type: ignore 
from tensorflow.keras.layers import Dropout                                  # type: ignore 
from tensorflow.keras.preprocessing.image import ImageDataGenerator          # type: ignore 

from tensorflow.keras.callbacks import EarlyStopping                         # type: ignore


from tensorflow.keras.callbacks import ReduceLROnPlateau                      # type: ignore
from tensorflow.keras.layers import BatchNormalization                        # type: ignore
from tensorflow.keras.callbacks import ModelCheckpoint                       # type: ignore
import matplotlib.pyplot as plt

# %%
# SECTION 1 — TRAIN DATA AUGMENTATION : “image transformation machine” ----->  image processing pipeline ban rahi hai. (Optimized for pre-augmented data)

train_datagen = ImageDataGenerator(
    rescale=1./255,                   # Normalize pixel values from [0,255] to [0,1]
    rotation_range=20,                # Apply small random rotations for better orientation invariance
    zoom_range=0.1,                   # Apply slight zoom while preserving important leaf features
    horizontal_flip=True,             # Simulate different horizontal leaf orientations
    vertical_flip=False,              # Disabled because leaves are rarely upside-down in real-world conditions
    width_shift_range=0.1,            # Randomly shift images horizontally
    height_shift_range=0.1,           # Randomly shift images vertically
    brightness_range=[1.0, 1.2],      # Simulate natural lighting variations changed from apple because of difference in picture quality. 
    fill_mode='nearest'               # Fill empty pixels created after image transformations
)

# SECTION 2 - Validation data no augmentation (Same rahega)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# SECTION 3: TRAIN GENERATOR
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/01_train',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)

# SECTION 4: VALIDATION GENERATOR
val_generator = val_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/02_validate',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 5015 images belonging to 4 classes.
# Found 1070 images belonging to 4 classes.

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)

# %%
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 4
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 5 (Naya Heavy Block)
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Global Feature Aggregation (Outputs a 512-d vector now)
model.add(layers.GlobalAveragePooling2D())

# Single, Strong Dense Layer
model.add(layers.Dense(256, activation='relu'))    # Compress the extracted features from 512 to 256 neurons before classification to reduce model complexity and improve generalization.
model.add(Dropout(0.43))                           #  Hard regularizer for real-world images

# Output Layer
model.add(layers.Dense(4, activation='softmax'))
# Out:
# c:\Users\sanch\Documents\Git_hub\Streamlit-KrishiNetra\krishi_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,704,900 (6.50 MB)
#  Trainable params: 1,702,916 (6.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# UPDATED TRAINING BLOCK 

# Compile Model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# =======================================================================================================================================
# QUESTION: Why are we using the EarlyStopping callback?
# =======================================================================================================================================
# 1. PREVENTS OVERFITTING: Deep learning models tend to memorize training data over time, causing validation loss to shoot up. 
#    EarlyStopping monitors 'val_loss' and halts training the moment the model stops learning.
# 2. OPTIMAL WEIGHT RETRIEVAL: With 'restore_best_weights = True', it discards the overfitted weights of the final epoch and automatically
#    rolls back to save the absolute best weights achieved during the entire run.
# ========================================================================================================================================

# Balanced Callbacks (Patience adjusted for heavy real-world data)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=5,                  # Patience has been kept as 5 so that model can get its time to improve and learn new patterns from real world images.
    restore_best_weights=True    # Save the best weight where the validation loss is the least.
)





# =====================================================================================================================================
# QUESTION: Why are we utilizing a Learning Rate (LR) Scheduler?
# =====================================================================================================================================
# 1. DYNAMIC OPTIMIZATION: A static learning rate can cause the model to jump back and forth over the global minimum.
#    ReduceLROnPlateau dynamically shrinks the learning rate (by a factor of 0.3) when validation loss plateaus.
# 2. FINE-TUNING: It allows the optimizer to take large, aggressive steps at the beginning of training, and micro-precise, gentle steps 
#    at the end to perfectly land on the lowest possible loss.
# =====================================================================================================================================

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,                  # Sharp reduction for local minima escape
    patience=3,                  # Wait for 3 epochs before dropping LR
    verbose=1
)



# ==========================================================================================================================================
# QUESTION: Why are we using the ModelCheckpoint callback?
# ==========================================================================================================================================
# 1. HARDWARE FAIL-SAFE: Model training can take hours and can be abruptly interrupted by system crashes, power cuts, or memory overloads.
#    Checkpoint acts as a live backup directly on the hard drive.
# 2. AUTOMATIC SNAPSHOTTING: With 'save_best_only=True', it continuously overwrites the target file only when a better validation performance
#    is discovered.This guarantees that a production-ready '.keras' file is secured on disk.
# ==========================================================================================================================================

checkpoint = ModelCheckpoint(
    '../04_models/model_grapes_1.0.2.keras', 
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# 2. TRAINING
print("\n Training started on Balanced Real-World Dataset ........")
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs=23,                   # 23 Epochs perfectly locked
    callbacks=[early_stop, lr_scheduler, checkpoint] 
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
#  Training started on Balanced Real-World Dataset ........
# Epoch 1/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6805 - loss: 0.9563
# Epoch 1: val_loss improved from None to 13.48101, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 1: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.7452 - loss: 0.7088 - val_accuracy: 0.2579 - val_loss: 13.4810 - learning_rate: 0.0010
# Epoch 2/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8289 - loss: 0.4639
# Epoch 2: val_loss improved from 13.48101 to 5.53753, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 2: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.8407 - loss: 0.4298 - val_accuracy: 0.3944 - val_loss: 5.5375 - learning_rate: 0.0010
# Epoch 3/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.3459
# Epoch 3: val_loss improved from 5.53753 to 4.68508, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 3: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.8857 - loss: 0.3141 - val_accuracy: 0.4262 - val_loss: 4.6851 - learning_rate: 0.0010
# Epoch 4/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9200 - loss: 0.2393
# Epoch 4: val_loss improved from 4.68508 to 0.67119, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 4: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9200 - loss: 0.2423 - val_accuracy: 0.7925 - val_loss: 0.6712 - learning_rate: 0.0010
# Epoch 5/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 989ms/step - accuracy: 0.9346 - loss: 0.1972
# Epoch 5: val_loss did not improve from 0.67119
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9336 - loss: 0.2021 - val_accuracy: 0.4505 - val_loss: 2.5449 - learning_rate: 0.0010
# Epoch 6/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 992ms/step - accuracy: 0.9453 - loss: 0.1701
# Epoch 6: val_loss did not improve from 0.67119
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9492 - loss: 0.1587 - val_accuracy: 0.7551 - val_loss: 0.9595 - learning_rate: 0.0010
# Epoch 7/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 993ms/step - accuracy: 0.9513 - loss: 0.1530
# Epoch 7: val_loss improved from 0.67119 to 0.40566, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 7: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.9486 - loss: 0.1539 - val_accuracy: 0.8645 - val_loss: 0.4057 - learning_rate: 0.0010
# Epoch 8/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9607 - loss: 0.1160
# Epoch 8: val_loss did not improve from 0.40566
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.9581 - loss: 0.1235 - val_accuracy: 0.5140 - val_loss: 2.4168 - learning_rate: 0.0010
# Epoch 9/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 959ms/step - accuracy: 0.9628 - loss: 0.1032
# Epoch 9: val_loss improved from 0.40566 to 0.25430, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 9: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9603 - loss: 0.1203 - val_accuracy: 0.9075 - val_loss: 0.2543 - learning_rate: 0.0010
# Epoch 10/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 953ms/step - accuracy: 0.9637 - loss: 0.1054
# Epoch 10: val_loss improved from 0.25430 to 0.13193, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 10: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 156s 994ms/step - accuracy: 0.9665 - loss: 0.1005 - val_accuracy: 0.9486 - val_loss: 0.1319 - learning_rate: 0.0010
# Epoch 11/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9757 - loss: 0.0671
# Epoch 11: val_loss did not improve from 0.13193
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9709 - loss: 0.0813 - val_accuracy: 0.6645 - val_loss: 1.7219 - learning_rate: 0.0010
# Epoch 12/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9627 - loss: 0.1044
# Epoch 12: val_loss did not improve from 0.13193
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9695 - loss: 0.0875 - val_accuracy: 0.8178 - val_loss: 0.6650 - learning_rate: 0.0010
# Epoch 13/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9804 - loss: 0.0637
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 13: val_loss did not improve from 0.13193
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9777 - loss: 0.0718 - val_accuracy: 0.8299 - val_loss: 0.6427 - learning_rate: 0.0010
# Epoch 14/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9859 - loss: 0.0473
# Epoch 14: val_loss improved from 0.13193 to 0.05690, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 14: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.9870 - loss: 0.0421 - val_accuracy: 0.9822 - val_loss: 0.0569 - learning_rate: 2.0000e-04
# Epoch 15/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9903 - loss: 0.0271
# Epoch 15: val_loss improved from 0.05690 to 0.01241, saving model to ../04_models/model_grapes_1.0.2.keras
#
# Epoch 15: finished saving model to ../04_models/model_grapes_1.0.2.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9912 - loss: 0.0251 - val_accuracy: 0.9972 - val_loss: 0.0124 - learning_rate: 2.0000e-04
# Epoch 16/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 972ms/step - accuracy: 0.9906 - loss: 0.0303
# Epoch 16: val_loss did not improve from 0.01241
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9910 - loss: 0.0271 - val_accuracy: 0.9869 - val_loss: 0.0391 - learning_rate: 2.0000e-04
# Epoch 17/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.9934 - loss: 0.0182
# Epoch 17: val_loss did not improve from 0.01241
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9938 - loss: 0.0185 - val_accuracy: 0.9888 - val_loss: 0.0377 - learning_rate: 2.0000e-04
# Epoch 18/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.9941 - loss: 0.0171
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 18: val_loss did not improve from 0.01241
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9928 - loss: 0.0199 - val_accuracy: 0.9869 - val_loss: 0.0328 - learning_rate: 2.0000e-04
# Epoch 19/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - accuracy: 0.9949 - loss: 0.0152
# Epoch 19: val_loss did not improve from 0.01241
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 155s 984ms/step - accuracy: 0.9944 - loss: 0.0186 - val_accuracy: 0.9888 - val_loss: 0.0278 - learning_rate: 4.0000e-05
# Epoch 20/23
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.9962 - loss: 0.0116
# Epoch 20: val_loss did not improve from 0.01241
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 156s 992ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.9869 - val_loss: 0.0352 - learning_rate: 4.0000e-05

# %%
# Plotting A single Graph containing both Accuracy(Training and Validation) and Loss(Training and Validation) Graphs:

plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# SECTION 5: TEST GENERATOR (For evaluation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/03_test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False       # CRITICAL: Keep it false while Evaluation 
)
# Out:
# Found 1070 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

print("Evaluating model on test dataset...")

# 1. Finding Prediction over Test Images:
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Evaluating model on test dataset...
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step

# %%
# 2. True (Original) labels Finding :
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
#  SECTION A: OVERALL TEST ACCURACY : Overall evaluation on complete Dataset
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print("\n" + "="*50)
print(f"Final Test Accuracy: {test_acc*100:.2f}%")
print(f"Final Test Loss:     {test_loss:.4f}")
print("="*50 + "\n")
# Out:
# ==================================================
# Final Test Accuracy: 99.44%
# Final Test Loss:     0.0148
# ==================================================

# %%
# SECTION B: PRECISION, RECALL, F1-SCORE 
print("Classification Report (Class-wise Performance):")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report (Class-wise Performance):
#                                             precision    recall  f1-score   support
#
#                          Grape___Black_rot       0.99      0.98      0.99       263
#               Grape___Esca_(Black_Measles)       0.99      1.00      0.99       277
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       276
#                            Grape___healthy       1.00      1.00      1.00       254
#
#                                   accuracy                           0.99      1070
#                                  macro avg       0.99      0.99      0.99      1070
#                               weighted avg       0.99      0.99      0.99      1070

# %%
# SECTION C: CONFUSION MATRIX
# Isse pata chalega kaun sa plant disease kis dusre disease ke sath confuse ho raha hai
cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix - Grapes Model')
plt.ylabel('Actual Classes')
plt.xlabel('Predicted Classes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
