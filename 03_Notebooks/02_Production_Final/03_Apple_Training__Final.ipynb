# %%
import os                                     
import tensorflow as tf
from tensorflow.keras import layers, models                                  # type: ignore 
from tensorflow.keras.layers import Dropout                                  # type: ignore 
from tensorflow.keras.preprocessing.image import ImageDataGenerator              # type: ignore 
 
from tensorflow.keras.callbacks import EarlyStopping                         # type: ignore

from tensorflow.keras.callbacks import ReduceLROnPlateau                     # type: ignore
from tensorflow.keras.layers import BatchNormalization                    # type: ignore
from tensorflow.keras.callbacks import ModelCheckpoint                       # type: ignore
import matplotlib.pyplot as plt

# %%
# SECTION 1 — TRAIN DATA AUGMENTATION : “image transformation machine” ----->  image processing pipeline ban rahi hai. (Optimized for pre-augmented data)

train_datagen = ImageDataGenerator(
    rescale=1./255,                   # Normalize pixel values from [0,255] to [0,1]
    rotation_range=20,                # Apply small random rotations for better orientation invariance
    zoom_range=0.1,                   # Apply slight zoom while preserving important leaf features
    horizontal_flip=True,             # Simulate different horizontal leaf orientations
    vertical_flip=False,              # Disabled because leaves are rarely upside-down in real-world conditions
    width_shift_range=0.1,            # Randomly shift images horizontally
    height_shift_range=0.1,           # Randomly shift images vertically
    brightness_range=[0.9, 1.1],      # Simulate natural lighting variations
    fill_mode='nearest'               # Fill empty pixels created after image transformations
)

# SECTION 2 - Validation data no augmentation (Same rahega)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
# ======================================================================================================================================
# QUESTION: Why did we select a Batch Size of 32?
# ======================================================================================================================================
# 1. RESOURCE EFFICIENCY: Since training runs on the CPU, a batch size of 32 acts as a safe sweet spot. It prevents system RAM saturation
#    and laptop lagging/crashing, which often happens with larger batches (64 or 128).
# 2. HIGHER GENERALIZATION: Smaller batch sizes introduce slight stochastic"noise" during gradient updates. This noise is a blessing
#    in disguise—it helps the optimizer bounce out of shallow local minima, leading to better performance on unseen, real-world test data.
# ========================================================================================================================================

# SECTION 3: TRAIN GENERATOR
train_generator = train_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/01_train',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)

# SECTION 4: VALIDATION GENERATOR
val_generator = val_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/02_validate',
    target_size=(224,224),
    batch_size= 32,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 5200 images belonging to 4 classes.
# Found 1483 images belonging to 4 classes.

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy']

# %%
model = models.Sequential()

# Block 1
model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 2
model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 3
model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 4
model.add(layers.Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Block 5 (Naya Heavy Block)
model.add(layers.Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D((2,2)))

# Global Feature Aggregation (Outputs a 512-dimensional vector now)
model.add(layers.GlobalAveragePooling2D())

# Single, Strong Dense Layer
model.add(layers.Dense(256, activation='relu'))     # Compress the extracted features from 512 to 256 neurons before classification to reduce model complexity and improve generalization.
model.add(Dropout(0.4))                            #  Hard regularizer for real-world images

# Output Layer
model.add(layers.Dense(4, activation='softmax'))
# Out:
# c:\Users\sanch\Documents\Git_hub\Streamlit-KrishiNetra\krishi_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,704,900 (6.50 MB)
#  Trainable params: 1,702,916 (6.50 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# Compile Model

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# =======================================================================================================================================
# QUESTION: Why are we using the EarlyStopping callback?
# =======================================================================================================================================
# 1. PREVENTS OVERFITTING: Deep learning models tend to memorize training data over time, causing validation loss to shoot up. 
#    EarlyStopping monitors 'val_loss' and halts training the moment the model stops learning.
# 2. OPTIMAL WEIGHT RETRIEVAL: With 'restore_best_weights = True', it discards the overfitted weights of the final epoch and automatically
#    rolls back to save the absolute best weights achieved during the entire run.
# ========================================================================================================================================

# Balanced Callbacks (Patience adjusted for heavy real-world data)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience= 5,                   # Patience has been kept as 5 so that model can get its time to improve and learn new patterns from real world images.
    restore_best_weights=True      # Save the best weight where the validation loss is the least.
)




# ====================================================================================================================================
# QUESTION: Why are we utilizing a Learning Rate (LR) Scheduler?
# ====================================================================================================================================
# 1. DYNAMIC OPTIMIZATION: A static learning rate can cause the model to jump back and forth over the global minimum.
#    ReduceLROnPlateau dynamically shrinks the learning rate (by a factor of 0.3) when validation loss plateaus.
# 2. FINE-TUNING: It allows the optimizer to take large, aggressive steps at the beginning of training, and micro-precise, gentle steps 
#    at the end to perfectly land on the lowest possible loss.
# ====================================================================================================================================

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor = 0.2,                  # Sharp reduction for local minima escape
    patience = 3,                  # Wait for 3 epochs before dropping LR
    verbose = 1
)



# ==========================================================================================================================================
# QUESTION: Why are we using the ModelCheckpoint callback?
# ==========================================================================================================================================
# 1. HARDWARE FAIL-SAFE: Model training can take hours and can be abruptly interrupted by system crashes, power cuts, or memory overloads.
#    Checkpoint acts as a live backup directly on the hard drive.
# 2. AUTOMATIC SNAPSHOTTING: With 'save_best_only=True', it continuously overwrites the target file only when a better validation performance
#    is discovered.This guarantees that a production-ready '.keras' file is secured on disk.
# ==========================================================================================================================================

checkpoint = ModelCheckpoint(
    '../04_models/model_apple_21.1.8.keras', 
    monitor = 'val_loss',
    save_best_only = True,
    verbose = 1
)

# 2. TRAINING (Removed class_weight parameter as dataset is now balanced at ~2k each)
print("\n Training started on Balanced Real-World Dataset ........")
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs = 30,                      # Increased the number of epochs to 30 so that the model can get time to improve.
    callbacks=[early_stop, lr_scheduler, checkpoint] 
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
#  Training started on Balanced Real-World Dataset ........
# Epoch 1/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - accuracy: 0.6510 - loss: 1.0087
# Epoch 1: val_loss improved from None to 3.50407, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 1: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 164s 988ms/step - accuracy: 0.7379 - loss: 0.7377 - val_accuracy: 0.2913 - val_loss: 3.5041 - learning_rate: 0.0010
# Epoch 2/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 939ms/step - accuracy: 0.8398 - loss: 0.4520
# Epoch 2: val_loss improved from 3.50407 to 1.93286, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 2: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.8552 - loss: 0.4097 - val_accuracy: 0.4080 - val_loss: 1.9329 - learning_rate: 0.0010
# Epoch 3/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.8899 - loss: 0.3031
# Epoch 3: val_loss improved from 1.93286 to 0.59841, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 3: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 959ms/step - accuracy: 0.9010 - loss: 0.2785 - val_accuracy: 0.7977 - val_loss: 0.5984 - learning_rate: 0.0010
# Epoch 4/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - accuracy: 0.9202 - loss: 0.2241
# Epoch 4: val_loss improved from 0.59841 to 0.30949, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 4: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 960ms/step - accuracy: 0.9244 - loss: 0.2072 - val_accuracy: 0.8840 - val_loss: 0.3095 - learning_rate: 0.0010
# Epoch 5/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9229 - loss: 0.2286
# Epoch 5: val_loss improved from 0.30949 to 0.18275, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 5: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 979ms/step - accuracy: 0.9308 - loss: 0.2011 - val_accuracy: 0.9440 - val_loss: 0.1827 - learning_rate: 0.0010
# Epoch 6/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9528 - loss: 0.1388
# Epoch 6: val_loss did not improve from 0.18275
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 978ms/step - accuracy: 0.9533 - loss: 0.1315 - val_accuracy: 0.9386 - val_loss: 0.1892 - learning_rate: 0.0010
# Epoch 7/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.9581 - loss: 0.1159
# Epoch 7: val_loss did not improve from 0.18275
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 964ms/step - accuracy: 0.9592 - loss: 0.1146 - val_accuracy: 0.9123 - val_loss: 0.3072 - learning_rate: 0.0010
# Epoch 8/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 942ms/step - accuracy: 0.9619 - loss: 0.1070
# Epoch 8: val_loss improved from 0.18275 to 0.18248, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 8: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.9608 - loss: 0.1119 - val_accuracy: 0.9299 - val_loss: 0.1825 - learning_rate: 0.0010
# Epoch 9/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - accuracy: 0.9704 - loss: 0.0873
# Epoch 9: val_loss did not improve from 0.18248
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9658 - loss: 0.1056 - val_accuracy: 0.9238 - val_loss: 0.2386 - learning_rate: 0.0010
# Epoch 10/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.9629 - loss: 0.1014
# Epoch 10: val_loss did not improve from 0.18248
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 159s 975ms/step - accuracy: 0.9623 - loss: 0.0999 - val_accuracy: 0.8321 - val_loss: 0.6644 - learning_rate: 0.0010
# Epoch 11/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 932ms/step - accuracy: 0.9663 - loss: 0.1010
# Epoch 11: val_loss improved from 0.18248 to 0.13140, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 11: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 162s 991ms/step - accuracy: 0.9656 - loss: 0.1039 - val_accuracy: 0.9582 - val_loss: 0.1314 - learning_rate: 0.0010
# Epoch 12/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 930ms/step - accuracy: 0.9809 - loss: 0.0635
# Epoch 12: val_loss improved from 0.13140 to 0.10110, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 12: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 161s 990ms/step - accuracy: 0.9788 - loss: 0.0648 - val_accuracy: 0.9697 - val_loss: 0.1011 - learning_rate: 0.0010
# Epoch 13/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9786 - loss: 0.0625
# Epoch 13: val_loss did not improve from 0.10110
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 161s 990ms/step - accuracy: 0.9733 - loss: 0.0778 - val_accuracy: 0.9447 - val_loss: 0.1873 - learning_rate: 0.0010
# Epoch 14/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 929ms/step - accuracy: 0.9751 - loss: 0.0746
# Epoch 14: val_loss improved from 0.10110 to 0.06010, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 14: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 161s 988ms/step - accuracy: 0.9762 - loss: 0.0762 - val_accuracy: 0.9825 - val_loss: 0.0601 - learning_rate: 0.0010
# Epoch 15/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - accuracy: 0.9759 - loss: 0.0782
# Epoch 15: val_loss did not improve from 0.06010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 979ms/step - accuracy: 0.9790 - loss: 0.0672 - val_accuracy: 0.9764 - val_loss: 0.0748 - learning_rate: 0.0010
# Epoch 16/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - accuracy: 0.9806 - loss: 0.0533
# Epoch 16: val_loss did not improve from 0.06010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 980ms/step - accuracy: 0.9773 - loss: 0.0609 - val_accuracy: 0.9090 - val_loss: 0.2868 - learning_rate: 0.0010
# Epoch 17/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - accuracy: 0.9768 - loss: 0.0639
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 17: val_loss did not improve from 0.06010
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 158s 970ms/step - accuracy: 0.9767 - loss: 0.0622 - val_accuracy: 0.9346 - val_loss: 0.2855 - learning_rate: 0.0010
# Epoch 18/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 925ms/step - accuracy: 0.9867 - loss: 0.0432
# Epoch 18: val_loss improved from 0.06010 to 0.03752, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 18: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 160s 984ms/step - accuracy: 0.9885 - loss: 0.0343 - val_accuracy: 0.9872 - val_loss: 0.0375 - learning_rate: 2.0000e-04
# Epoch 19/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 903ms/step - accuracy: 0.9928 - loss: 0.0237
# Epoch 19: val_loss did not improve from 0.03752
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 962ms/step - accuracy: 0.9921 - loss: 0.0252 - val_accuracy: 0.9852 - val_loss: 0.0404 - learning_rate: 2.0000e-04
# Epoch 20/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - accuracy: 0.9921 - loss: 0.0249
# Epoch 20: val_loss improved from 0.03752 to 0.03537, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 20: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 960ms/step - accuracy: 0.9915 - loss: 0.0274 - val_accuracy: 0.9865 - val_loss: 0.0354 - learning_rate: 2.0000e-04
# Epoch 21/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 905ms/step - accuracy: 0.9941 - loss: 0.0170
# Epoch 21: val_loss improved from 0.03537 to 0.02949, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 21: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 963ms/step - accuracy: 0.9952 - loss: 0.0157 - val_accuracy: 0.9919 - val_loss: 0.0295 - learning_rate: 2.0000e-04
# Epoch 22/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.9948 - loss: 0.0168
# Epoch 22: val_loss did not improve from 0.02949
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 964ms/step - accuracy: 0.9929 - loss: 0.0194 - val_accuracy: 0.9933 - val_loss: 0.0330 - learning_rate: 2.0000e-04
# Epoch 23/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 908ms/step - accuracy: 0.9935 - loss: 0.0177
# Epoch 23: val_loss improved from 0.02949 to 0.02801, saving model to ../04_models/model_apple_21.1.8.keras
#
# Epoch 23: finished saving model to ../04_models/model_apple_21.1.8.keras
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 158s 966ms/step - accuracy: 0.9944 - loss: 0.0156 - val_accuracy: 0.9919 - val_loss: 0.0280 - learning_rate: 2.0000e-04
# Epoch 24/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 912ms/step - accuracy: 0.9919 - loss: 0.0186
# Epoch 24: val_loss did not improve from 0.02801
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 158s 971ms/step - accuracy: 0.9938 - loss: 0.0177 - val_accuracy: 0.9926 - val_loss: 0.0339 - learning_rate: 2.0000e-04
# Epoch 25/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.9951 - loss: 0.0198
# Epoch 25: val_loss did not improve from 0.02801
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 159s 977ms/step - accuracy: 0.9944 - loss: 0.0180 - val_accuracy: 0.9912 - val_loss: 0.0370 - learning_rate: 2.0000e-04
# Epoch 26/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - accuracy: 0.9958 - loss: 0.0137
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 26: val_loss did not improve from 0.02801
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 157s 962ms/step - accuracy: 0.9948 - loss: 0.0151 - val_accuracy: 0.9906 - val_loss: 0.0394 - learning_rate: 2.0000e-04
# Epoch 27/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 918ms/step - accuracy: 0.9945 - loss: 0.0145
# Epoch 27: val_loss did not improve from 0.02801
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 159s 977ms/step - accuracy: 0.9956 - loss: 0.0129 - val_accuracy: 0.9919 - val_loss: 0.0362 - learning_rate: 4.0000e-05
# Epoch 28/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - accuracy: 0.9969 - loss: 0.0116
# Epoch 28: val_loss did not improve from 0.02801
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 158s 966ms/step - accuracy: 0.9971 - loss: 0.0112 - val_accuracy: 0.9912 - val_loss: 0.0351 - learning_rate: 4.0000e-05

# %%
# Plotting A single Graph containing both Accuracy(Training and Validation) and Loss(Training and Validation) Graphs:

plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# SECTION 5: TEST GENERATOR (For evaluation)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    'C:/Users/sanch/Documents/Git_hub/Streamlit-KrishiNetra/02_dataset/03_test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # CRITICAL: Keep it false while Evaluation 
)
# Out:
# Found 740 images belonging to 4 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

print("Evaluating model on test dataset...")

# 1. Finding Prediction over Test Images:
predictions = model.predict(test_generator, verbose=1)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Evaluating model on test dataset...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step

# %%
# 2. True (Original) labels Finding:
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
#  SECTION A: OVERALL TEST ACCURACY : Overall evaluation on complete Dataset
test_loss, test_acc = model.evaluate(test_generator, verbose=0)
print("\n" + "="*50)
print(f"Final Test Accuracy: {test_acc*100:.2f}%")
print(f"Final Test Loss:     {test_loss:.4f}")
print("="*50 + "\n")
# Out:
# ==================================================
# Final Test Accuracy: 99.19%
# Final Test Loss:     0.0307
# ==================================================

# %%
# SECTION B: PRECISION, RECALL, F1-SCORE 
print("Classification Report (Class-wise Performance):")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))
# Out:
# Classification Report (Class-wise Performance):
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       1.00      0.98      0.99       186
#        Apple___Black_rot       0.99      0.99      0.99       190
# Apple___Cedar_apple_rust       0.99      0.99      0.99       176
#          Apple___healthy       0.98      1.00      0.99       188
#
#                 accuracy                           0.99       740
#                macro avg       0.99      0.99      0.99       740
#             weighted avg       0.99      0.99      0.99       740

# %%
# --- SECTION C: CONFUSION MATRIX ---
# This will make us clear that which plant is getting confused with which different disease

cm = confusion_matrix(true_classes, predicted_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix - Apple :) Model')
plt.ylabel('Actual Classes')
plt.xlabel('Predicted Classes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
